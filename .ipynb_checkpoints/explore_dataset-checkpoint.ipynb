# %%
import numpy as np

with np.load('data/processed_data.npz') as data:
  print("Arrays in file:")
  for name in data.files:
    print(f"  {name}: shape={data[name].shape}, dtype={data[name].dtype}")

  images = data.files[0]
  labels = data.files[1]

  print(f"{images.shape}, {labels.shape}")
# Out:
# Arrays in file:
#   images: shape=(18932, 128, 128), dtype=float32
#   labels: shape=(18932,), dtype=int64
# m, a
